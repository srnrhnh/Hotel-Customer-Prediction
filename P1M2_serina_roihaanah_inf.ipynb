# %%
import pandas as pd
import numpy as np

import pickle
import json

# %%
# load model

# load model yang udah dibuat
with open('model.pkl', 'rb') as file_1:
    model = pickle.load(file_1)

# %%
model
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    MinMaxScaler())]),
#                                                   ['lead_time',
#                                                    'stays_in_week_nights',
#                                                    'adults', 'babies',
#                                                    'previous_cancellations',
#                                                    'previous_bookings_not_canceled',
#                                                    'booking_changes',
#                                                    'days_in_waiting_list',
#                                                    'adr',
#                                                    'required_car_parking_spaces',
# ...

# %%
# Save random data
data= {'hotel': ['City Hotel', 'City Hotel'],
 'lead_time': [115, 195],
 'arrival_date_year': [2017, 2015],
 'arrival_date_month': ['May', 'September'],
 'arrival_date_week_number': [21, 38],
 'arrival_date_day_of_month': [22, 17],
 'stays_in_weekend_nights': [1, 0],
 'stays_in_week_nights': [2, 2],
 'adults': [2, 2],
 'children': [0.0, 0.0],
 'babies': [0, 0],
 'meal': ['BB', 'BB'],
 'country': ['FRA', 'PRT'],
 'market_segment': ['Online TA', 'Offline TA/TO'],
 'distribution_channel': ['TA/TO', 'TA/TO'],
 'is_repeated_guest': [0, 0],
 'previous_cancellations': [0, 1],
 'previous_bookings_not_canceled': [0, 0],
 'reserved_room_type': ['A', 'A'],
 'assigned_room_type': ['A', 'A'],
 'booking_changes': [0, 0],
 'deposit_type': ['No Deposit', 'No Deposit'],
 'days_in_waiting_list': [0, 0],
 'customer_type': ['Transient', 'Transient'],
 'adr': [135.0, 48.0],
 'required_car_parking_spaces': [0, 0],
 'total_of_special_requests': [4, 0],
 'reservation_status': ['Check-Out', 'Canceled'],
 'reservation_status_date': [pd.Timestamp('2017-05-25 00:00:00'),
  pd.Timestamp('2015-07-23 00:00:00')],
 'name': ['Jeffrey Henry', 'Jorge Bullock'],
 'email': ['Jeffrey_H@gmail.com', 'Jorge_Bullock@yandex.com'],
 'phone-number': ['250-438-0038', '432-182-4135'],
 'credit_card': ['************6079', '************8340'],
 'month': [5, 7]}

df_inf = pd.DataFrame(data)

# %%
# save prediction model
prediction = model.predict(df_inf)

# %%
prediction
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# Customer dengan nama Jeffrey Henry terprediksi tidak akan melakukan pembatalan, sedangkan customer bernama Jorge Bullock terprediksi akan melakukan pembatalan.
